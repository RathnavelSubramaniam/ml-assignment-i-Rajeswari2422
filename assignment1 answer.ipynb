# %% [markdown]
# # 1	This exercise involves the Auto data set studied in the lab. Make sure that the missing values have been removed from the data.

# %%
 from ISLP import load_data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
auto = load_data("auto")
auto
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0         130    3504          12.0    70
# 1    15.0          8         350.0         165    3693          11.5    70
# 2    18.0          8         318.0         150    3436          11.0    70
# 3    16.0          8         304.0         150    3433          12.0    70
# 4    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 387  27.0          4         140.0          86    2790          15.6    82
# 388  44.0          4          97.0          52    2130          24.6    82
# 389  32.0          4         135.0          84    2295          11.6    82
# 390  28.0          4         120.0          79    2625          18.6    82
# 391  31.0          4         119.0          82    2720          19.4    82
#
#      origin                       name
# ...

# %%
auto = auto.dropna()
auto
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0         130    3504          12.0    70
# 1    15.0          8         350.0         165    3693          11.5    70
# 2    18.0          8         318.0         150    3436          11.0    70
# 3    16.0          8         304.0         150    3433          12.0    70
# 4    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 387  27.0          4         140.0          86    2790          15.6    82
# 388  44.0          4          97.0          52    2130          24.6    82
# 389  32.0          4         135.0          84    2295          11.6    82
# 390  28.0          4         120.0          79    2625          18.6    82
# 391  31.0          4         119.0          82    2720          19.4    82
#
#      origin                       name
# ...

# %% [markdown]
# # a) Which of the predictors are quantitative, and which are qualitative?

# %%
auto.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower        int64
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %%
quantitative = auto.select_dtypes(include=['float64', 'int64'])
quantitative
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0         130    3504          12.0    70
# 1    15.0          8         350.0         165    3693          11.5    70
# 2    18.0          8         318.0         150    3436          11.0    70
# 3    16.0          8         304.0         150    3433          12.0    70
# 4    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 387  27.0          4         140.0          86    2790          15.6    82
# 388  44.0          4          97.0          52    2130          24.6    82
# 389  32.0          4         135.0          84    2295          11.6    82
# 390  28.0          4         120.0          79    2625          18.6    82
# 391  31.0          4         119.0          82    2720          19.4    82
#
#      origin
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %%
qualitative = auto.select_dtypes(include=['object'])
qualitative
# Out:
#                           name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ..                         ...
# 387            ford mustang gl
# 388                  vw pickup
# 389              dodge rampage
# 390                ford ranger
# 391                 chevy s-10
#
# [392 rows x 1 columns]

# %% [markdown]
# # b) What is the range of each quantitative predictor? You can answer this using the range() function.

# %%
col = ['mpg','cylinders','displacement','horsepower','weight','acceleration','year']
min = auto[col].min()
max = auto[col].max()
print(f"Range of {col}: {min} , {max}")
# Out:
# Range of ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year']: mpg                9.0
# cylinders          3.0
# displacement      68.0
# horsepower        46.0
# weight          1613.0
# acceleration       8.0
# year              70.0
# dtype: float64 , mpg               46.6
# cylinders          8.0
# displacement     455.0
# horsepower       230.0
# weight          5140.0
# acceleration      24.8
# year              82.0
# dtype: float64

# %% [markdown]
# # C) What is the mean and standard deviation of each quantitative predictor?

# %%
mean = auto[col].mean()
std = auto[col].std()
print(f"{col}: {mean} , Std Dev of {col}: {std}")
# Out:
# ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year']: mpg               23.445918
# cylinders          5.471939
# displacement     194.411990
# horsepower       104.469388
# weight          2977.584184
# acceleration      15.541327
# year              75.979592
# dtype: float64 , Std Dev of ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year']: mpg               7.805007
# cylinders         1.705783
# displacement    104.644004
# horsepower       38.491160
# weight          849.402560
# acceleration      2.758864
# year              3.683737
# dtype: float64

# %% [markdown]
# # d) Now remove the 10th through 85th observations. What is the range, mean, and standard deviation of each predictor in the subset of the data that remains?

# %%
auto_subset = auto.drop(auto.index[9:85])

# %%
min = auto_subset[col].min()
max = auto_subset[col].max()
mean = auto_subset[col].mean()
std = auto_subset[col].std()
print(f"Range of {col}: {min} , {max}")
print(f"Mean of {col}: {mean} , Std Dev of {col}: {std}")
# Out:
# Range of ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year']: mpg               11.0
# cylinders          3.0
# displacement      68.0
# horsepower        46.0
# weight          1649.0
# acceleration       8.5
# year              70.0
# dtype: float64 , mpg               46.6
# cylinders          8.0
# displacement     455.0
# horsepower       230.0
# weight          4997.0
# acceleration      24.8
# year              82.0
# dtype: float64
# Mean of ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year']: mpg               24.404430
# cylinders          5.373418
# displacement     187.240506
# horsepower       100.721519
# weight          2935.971519
# acceleration      15.726899
# year              77.145570
# dtype: float64 , Std Dev of ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year']: mpg               7.867283
# cylinders         1.654179
# displacement     99.678367
# ...

# %% [markdown]
# # e) Using the full data set, investigate the predictors graphically, using scatterplots or other tools of your choice. Create some plots highlighting the relationships among the predictors. Comment on your findings.

# %%
sns.scatterplot(auto[col])
plt.suptitle("Scatterplot of Auto Data")
plt.show()

# %% [markdown]
# # f)Suppose that we wish to predict gas mileage (mpg) on the basis of the other variables. Do your plots suggest that any of the other variables might be useful in predicting mpg? Justify your answer

# %%
sns.scatterplot(x='horsepower', y='mpg', data=auto)
plt.title('Horsepower vs MPG')
# Out:
# Text(0.5, 1.0, 'Horsepower vs MPG')

# %%
sns.scatterplot(x='weight', y='mpg', data=auto)
plt.title("MPG vs Weight")
# Out:
# Text(0.5, 1.0, 'MPG vs Weight')

# %%
sns.scatterplot(x='year', y='mpg', data=auto)
plt.title("MPG vs Year")
# Out:
# Text(0.5, 1.0, 'MPG vs Year')

# %%
sns.boxplot(x='cylinders', y='mpg', data=auto)
plt.title("MPG by Cylinders")
